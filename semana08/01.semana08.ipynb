# %% [markdown]
# # Regressão Linear

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np

df_train = pd.read_csv('train.csv').fillna(0)
df_test = pd.read_csv('test.csv').fillna(0)

x_train = df_train['x']
y_train = df_train['y']
x_test = df_test['x']
y_test = df_test['y']

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
df_train
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 995  71.0  68.545888
# 996  46.0  47.334876
# 997  55.0  54.090637
# 998  62.0  63.297171
# 999  47.0  52.459467
#
# [1000 rows x 2 columns]

# %%
sns.scatterplot(x='x',y='y', data=df_train[df_train.x <= 3500])

# %%
sns.scatterplot(x='x',y='y', data=df_test)

# %%
x_train
# Out:
# array([[2.40000000e+01],
#        [5.00000000e+01],
#        [1.50000000e+01],
#        [3.80000000e+01],
#        [8.70000000e+01],
#        [3.60000000e+01],
#        [1.20000000e+01],
#        [8.10000000e+01],
#        [2.50000000e+01],
#        [5.00000000e+00],
#        [1.60000000e+01],
#        [1.60000000e+01],
#        [2.40000000e+01],
#        [3.90000000e+01],
#        [5.40000000e+01],
#        [6.00000000e+01],
#        [2.60000000e+01],
#        [7.30000000e+01],
#        [2.90000000e+01],
#        [3.10000000e+01],
#        [6.80000000e+01],
#        [8.70000000e+01],
#        [5.80000000e+01],
#        [5.40000000e+01],
#        [8.40000000e+01],
#        [5.80000000e+01],
#        [4.90000000e+01],
#        [2.00000000e+01],
#        [9.00000000e+01],
#        [4.80000000e+01],
#        [4.00000000e+00],
#        [2.50000000e+01],
#        [4.20000000e+01],
#        [0.00000000e+00],
#        [6.00000000e+01],
#        [9.30000000e+01],
#        [3.90000000e+01],
# ...

# %%
x_test
# Out:
# array([[ 77],
#        [ 21],
#        [ 22],
#        [ 20],
#        [ 36],
#        [ 15],
#        [ 62],
#        [ 95],
#        [ 20],
#        [  5],
#        [  4],
#        [ 19],
#        [ 96],
#        [ 62],
#        [ 36],
#        [ 15],
#        [ 65],
#        [ 14],
#        [ 87],
#        [ 69],
#        [ 89],
#        [ 51],
#        [ 89],
#        [ 27],
#        [ 97],
#        [ 58],
#        [ 79],
#        [ 21],
#        [ 93],
#        [ 27],
#        [ 99],
#        [ 31],
#        [ 33],
#        [ 80],
#        [ 28],
#        [ 47],
#        [ 53],
#        [ 69],
#        [ 28],
#        [ 33],
#        [ 91],
#        [ 71],
#        [ 50],
#        [ 76],
#        [  4],
#        [ 37],
#        [ 70],
#        [ 68],
#        [ 40],
#        [ 35],
#        [ 94],
#        [ 88],
#        [ 52],
#        [ 31],
#        [ 59],
#        [  0],
#        [ 39],
#        [ 64],
#        [ 69],
#        [ 57],
#        [ 13],
#        [ 72],
# ...

# %%
from sklearn.linear_model import LinearRegression ,Ridge
from sklearn.metrics import r2_score
clf = LinearRegression(normalize=True)
clf.fit(x_train,y_train)
y_pred_linear = clf.predict(x_test)
print(r2_score(y_test,y_pred_linear))
# Out:
# 0.09530593063444781

# %%
clf = Ridge(normalize=True)
clf.fit(x_train,y_train)
y_pred_ridge = clf.predict(x_test)
print(r2_score(y_test,y_pred_ridge)*100)
# Out:
# 4.776107466384949

# %%
df_pred = df_test
df_pred['y_liner'] = y_pred_linear
df_pred['y_rid'] = y_pred_ridge
df_pred
# Out:
#       x          y    y_liner      y_rid
# 0    77  79.775152  51.450719  50.860101
# 1    21  23.177279  48.603003  49.436243
# 2    22  25.609262  48.653855  49.461669
# 3    20  17.857388  48.552151  49.410817
# 4    36  41.849864  49.365784  49.817634
# ..   ..        ...        ...        ...
# 295  71  68.545888  51.145606  50.707545
# 296  46  47.334876  49.874304  50.071894
# 297  55  54.090637  50.331973  50.300728
# 298  62  63.297171  50.687938  50.478711
# 299  47  52.459467  49.925157  50.097320
#
# [300 rows x 4 columns]

# %%
sns.scatterplot(x='x',y='y_liner', data=df_pred,color='red')
sns.scatterplot(x='x',y='y_rid', data=df_pred,color='yellow')
sns.scatterplot(x='x',y='y', data=df_pred,color='blue')

# %%
import random
df_train['f1']  = df_train['x'].apply(lambda x: x * random.random())

# %%
df_train
# Out:
#         x          y         f1
# 0    24.0  21.549452   6.701458
# 1    50.0  47.464463  18.972381
# 2    15.0  17.218656   9.560768
# 3    38.0  36.586398  22.164670
# 4    87.0  87.288984  57.193736
# ..    ...        ...        ...
# 995  71.0  68.545888  38.672896
# 996  46.0  47.334876  44.398610
# 997  55.0  54.090637  22.450363
# 998  62.0  63.297171  14.718317
# 999  47.0  52.459467  21.465908
#
# [1000 rows x 3 columns]

# %%
features = ['x','f1']
df_x_treino = df_train[features]
df_y_treino = df_train.y

# %%
model  = LinearRegression()

# %%
ln = model.fit(df_x_treino,df_y_treino)

# %%
df_test['f1']  = df_test['x'].apply(lambda x: x * random.random())

# %%
df_test
# Out:
#       x          y    y_liner      y_rid         f1
# 0    77  79.775152  51.450719  50.860101  54.010656
# 1    21  23.177279  48.603003  49.436243  12.581517
# 2    22  25.609262  48.653855  49.461669  14.212142
# 3    20  17.857388  48.552151  49.410817  18.773443
# 4    36  41.849864  49.365784  49.817634  28.525929
# ..   ..        ...        ...        ...        ...
# 295  71  68.545888  51.145606  50.707545  43.360511
# 296  46  47.334876  49.874304  50.071894  40.416830
# 297  55  54.090637  50.331973  50.300728  36.391892
# 298  62  63.297171  50.687938  50.478711  14.154728
# 299  47  52.459467  49.925157  50.097320   6.250147
#
# [300 rows x 5 columns]

# %%
features = ['x','f1']
df_x_test = df_test[features]
df_y_test = df_test.y

# %%
y_pred_2 = ln.predict(df_x_test)

# %%
df_pred_2 = df_test
df_pred_2['y_liner'] = y_pred_2
df_pred_2
# Out:
#       x          y    y_liner      y_rid         f1
# 0    77  79.775152  57.933332  50.860101  54.010656
# 1    21  23.177279  48.295350  49.436243  12.581517
# 2    22  25.609262  48.775428  49.461669  14.212142
# 3    20  17.857388  50.519655  49.410817  18.773443
# 4    36  41.849864  52.552750  49.817634  28.525929
# ..   ..        ...        ...        ...        ...
# 295  71  68.545888  54.753342  50.707545  43.360511
# 296  46  47.334876  55.827065  50.071894  40.416830
# 297  55  54.090637  53.682675  50.300728  36.391892
# 298  62  63.297171  45.409337  50.478711  14.154728
# 299  47  52.459467  43.931436  50.097320   6.250147
#
# [300 rows x 5 columns]

# %%
print(r2_score(df_y_test,y_pred_2))
# Out:
# 0.13547187091882407

# %%
sns.scatterplot(x='x',y='y_liner', data=df_pred_2,color='red')
sns.scatterplot(x='x',y='y', data=df_pred_2,color='blue')

# %%
from sklearn.linear_model import LinearRegression ,Ridge
from sklearn.metrics import r2_score
clf = LinearRegression(normalize=True)
clf.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
import pickle

# %%
dogs_dict = { 'Ozzy': 3, 'Filou': 8, 'Luna': 5, 'Skippy': 10, 'Barco': 12, 'Balou': 9, 'Laika': 16 }

# %%
filename = 'dogs.pkl'
outfile = open(filename,'wb')
pickle.dump(dogs_dict,outfile)
outfile.close()

# %%
infile = open(filename,'rb')
new_dict = pickle.load(infile)
infile.close()
print(new_dict)
# Out:
# {'Ozzy': 3, 'Filou': 8, 'Luna': 5, 'Skippy': 10, 'Barco': 12, 'Balou': 9, 'Laika': 16}

# %%
filename = 'linear.pkl'
outfile = open(filename,'wb')
pickle.dump(clf,outfile)
outfile.close()

# %%
y_pred_linear = clf.predict(x_test)
print(r2_score(y_test,y_pred_linear))
# Out:
# 0.09530593063444781

# %%
infile = open(filename,'rb')
new_linear = pickle.load(infile)
infile.close()

# %%
y_pred_linear = new_linear.predict(x_test)
print(r2_score(y_test,y_pred_linear))
# Out:
# 0.09530593063444781

# %%
new_linear.rank_
# Out:
# 1

# %%
df_train
# Out:
#         x          y         f1
# 0    24.0  21.549452   6.701458
# 1    50.0  47.464463  18.972381
# 2    15.0  17.218656   9.560768
# 3    38.0  36.586398  22.164670
# 4    87.0  87.288984  57.193736
# ..    ...        ...        ...
# 995  71.0  68.545888  38.672896
# 996  46.0  47.334876  44.398610
# 997  55.0  54.090637  22.450363
# 998  62.0  63.297171  14.718317
# 999  47.0  52.459467  21.465908
#
# [1000 rows x 3 columns]

# %%
filename = 'df.pkl'
outfile = open(filename,'wb')
pickle.dump(df_train,outfile)
outfile.close()

# %%
infile = open(filename,'rb')
new_df = pickle.load(infile)
infile.close()

# %%
new_df
# Out:
#         x          y         f1
# 0    24.0  21.549452   6.701458
# 1    50.0  47.464463  18.972381
# 2    15.0  17.218656   9.560768
# 3    38.0  36.586398  22.164670
# 4    87.0  87.288984  57.193736
# ..    ...        ...        ...
# 995  71.0  68.545888  38.672896
# 996  46.0  47.334876  44.398610
# 997  55.0  54.090637  22.450363
# 998  62.0  63.297171  14.718317
# 999  47.0  52.459467  21.465908
#
# [1000 rows x 3 columns]
