# %% [markdown]
# # XP Data Science - Semana 5 - Pensamento estatístico em Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sct
import seaborn as sns

# %%
from IPython.core.pylabtools import figsize
figsize(12, 8)
sns.set()

# %% [markdown]
# ## Valores aleatórios para testarmos

# %%
# Criando valores aleatórios de média 5 e desvio padrão 3
x_10 = sct.norm.rvs(loc=5, scale=3, size=10)
x_50 = sct.norm.rvs(loc=5, scale=3, size=50)
x_100 = sct.norm.rvs(loc=5, scale=3, size=100)
x_1000 = sct.norm.rvs(loc=5, scale=3, size=1000)
x_10000 = sct.norm.rvs(loc=5, scale=3, size=10000)
x_100000 = sct.norm.rvs(loc=5, scale=3, size=100000)

# %% [markdown]
# ## Histograma

# %%
plt.hist(x_50)
# Out:
# (array([ 2.,  1.,  0.,  8., 10.,  8.,  9., 10.,  1.,  1.]),
#  array([-2.56506248, -1.05941202,  0.44623843,  1.95188889,  3.45753935,
#          4.96318981,  6.46884027,  7.97449072,  9.48014118, 10.98579164,
#         12.4914421 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Shapiro

# %%
print(sct.shapiro(x_10))
print(sct.shapiro(x_50))
print(sct.shapiro(x_100))
print(sct.shapiro(x_1000))
print(sct.shapiro(x_10000))
print(sct.shapiro(x_100000))
# Out:
# (0.8521565794944763, 0.06162174418568611)
# (0.9641268849372864, 0.13234415650367737)
# (0.9819126129150391, 0.18682892620563507)
# (0.9989840984344482, 0.8648604154586792)
# (0.9997596144676208, 0.31528204679489136)
# (0.9999710321426392, 0.6334275603294373)
# /home/gabriel/.virtualenvs/codenation/lib/python3.7/site-packages/scipy/stats/morestats.py:1660: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# ## QQPlot

# %%
import statsmodels.api as sm
sm.qqplot(x_10,line='s')
sm.qqplot(x_50, line='s')
sm.qqplot(x_100, line='s')
sm.qqplot(x_1000, line='s')
plt.show()

# %% [markdown]
# ## Jarque

# %%
print(sct.jarque_bera(x_10))
print(sct.jarque_bera(x_50))
print(sct.jarque_bera(x_100))
print(sct.jarque_bera(x_1000))
print(sct.jarque_bera(x_10000))
print(sct.jarque_bera(x_100000))
# Out:
# (3.185583507457924, 0.20335709559499526)
# (3.762702324874379, 0.15238407096228146)
# (1.8878906222181318, 0.38908972318082224)
# (0.9839044749848835, 0.6114315686399221)
# (2.058011178140473, 0.35736214876498196)
# (3.136469450819104, 0.20841276357653926)

# %% [markdown]
# ## Normal Test

# %%
print(sct.normaltest(x_10))
print(sct.normaltest(x_50))
print(sct.normaltest(x_100))
print(sct.normaltest(x_1000))
print(sct.normaltest(x_10000))
print(sct.normaltest(x_100000))
# Out:
# NormaltestResult(statistic=8.074503505921049, pvalue=0.017645901133651064)
# NormaltestResult(statistic=4.8711894989575875, pvalue=0.08754566382342792)
# NormaltestResult(statistic=1.8774932653963678, pvalue=0.39111774246718006)
# NormaltestResult(statistic=0.9103440473398399, pvalue=0.6343388372672076)
# NormaltestResult(statistic=2.105720376607031, pvalue=0.3489382912543784)
# NormaltestResult(statistic=3.1701203635052977, pvalue=0.20493545937054294)
# /home/gabriel/.virtualenvs/codenation/lib/python3.7/site-packages/scipy/stats/stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   "anyway, n=%i" % int(n))

# %% [markdown]
# ## Log ?

# %%
normal_array = [1, 1.2, 1.4, 1.6, 1.8, 2,100,500,500,600,2000] 
log_array = np.log(normal_array) 
  
print ("normal_array : ", normal_array) 
  
plt.plot(normal_array,   color = 'blue', marker = "*")
# Out:
# normal_array :  [1, 1.2, 1.4, 1.6, 1.8, 2, 100, 500, 500, 600, 2000]

# %%
  
# red for numpy.log() 
plt.plot(log_array , color = 'red', marker = "o")

# %%
plt.hist(normal_array)
# Out:
# (array([7., 0., 3., 0., 0., 0., 0., 0., 0., 1.]),
#  array([1.0000e+00, 2.0090e+02, 4.0080e+02, 6.0070e+02, 8.0060e+02,
#         1.0005e+03, 1.2004e+03, 1.4003e+03, 1.6002e+03, 1.8001e+03,
#         2.0000e+03]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(log_array)
# Out:
# (array([6., 0., 0., 0., 0., 0., 1., 0., 3., 1.]),
#  array([0.        , 0.76009025, 1.52018049, 2.28027074, 3.04036098,
#         3.80045123, 4.56054148, 5.32063172, 6.08072197, 6.84081221,
#         7.60090246]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Ainda vamos falar de vinho !

# %%
wine = pd.read_csv('wine-data.csv')
wine.head(3)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
#
#     designation  points  price           province           region_1  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1      Avidagos      87   15.0              Douro                NaN
# 2           NaN      87   14.0             Oregon  Willamette Valley
#
#             region_2    taster_name taster_twitter_handle  \
# 0                NaN  Kerin O’Keefe          @kerinokeefe
# 1                NaN     Roger Voss            @vossroger
# 2  Willamette Valley   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm

# %% [markdown]
# ## Paises

# %%
wine.country.unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %% [markdown]
# ### Será que eu engano com um Brasil ou Frances ?

# %%
br = wine[wine.country=='Brazil']
br.price.hist()

# %%
fr = wine[wine.country=='France']
fr.price.hist()

# %%
fr.price.isna().any()
# Out:
# True

# %%
sct.ttest_ind(br.price,fr.price,nan_policy='omit')
# Out:
# Ttest_indResult(statistic=-1.6144580723850368, pvalue=0.10644580795345383)

# %%
fr.price.std()
# Out:
# 73.76940425778103

# %%
br.price.std()
# Out:
# 11.053649340253212

# %%
sm.qqplot(br.price,line='s')
plt.show()

# %%
sm.qqplot(fr.price,line='s')
plt.show()

# %%
sns.boxplot(br.price)

# %%
sns.boxplot(fr.price)
